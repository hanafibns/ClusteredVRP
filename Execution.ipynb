# %%
# %run "Execution.py"
# Out:
# k =  21
# ______________________________________________________
# ______________________________________________________
# ______________________________________________________
# ______________________________________________________
# ______________________________________________________
# cluster final  [[2, 12, 20, 61], [6, 63, 65], [10, 19, 26, 33, 40, 55, 77], [5, 38, 58, 62, 67, 71], [13, 28, 35, 47, 60], [16, 42, 45, 51], [1, 30, 49, 57], [27, 32, 48, 81], [86, 87, 95], [50, 56, 64, 66, 93], [37, 41, 43, 92], [25, 72, 80, 89], [14, 68, 84, 85, 98], [3, 17, 78, 88, 94], [34, 74, 75, 82, 91], [4, 21, 22, 90], [0, 18, 31, 52, 69, 83], [8, 23, 29, 39, 59], [9, 24, 36, 46, 73, 79], [53, 54, 70, 76], [7, 11, 15, 44, 97]]
# La tournée:  [0, 2, 20, 12, 61, 0]
# Distance de la tournée:  16.0
# ____________________________________
# La tournée:  [0, 63, 6, 65, 0]
# Distance de la tournée:  52.0
# ____________________________________
# La tournée:  [0, 10, 19, 55, 26, 77, 33, 40, 0]
# ...
